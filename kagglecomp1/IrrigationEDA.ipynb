# %% [markdown]
# # Kaggle Competition - EDA for Predicting Irrigation Need
#
# **Name:** Christine Wu
# **Date:** 04/13/26

# %%
import sweetviz as sv
import pandas as pd
import numpy as np

# loading the dataset
irrigation = pd.read_csv('/Users/christinewu/Desktop/academic resources/Advanced Machine Learning/Homework Files/Homework1- Kaggle Competition/CSV Files/train.csv')

# performing EDA with SweetViz
report = sv.analyze(irrigation)
report.show_html('irrigation_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report irrigation_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
